# %%
## Naive Baye's Algo

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
X,y = load_iris(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(y_test,y_pred)
confusion_matrix(y_test,y_pred)
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.93      1.00      0.96        13
#            2       1.00      0.83      0.91         6
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.94      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# 0.9666666666666667

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
## Feature Engineering
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
X = df[['total_bill', 'tip', 'sex', 'smoker', 'day']] ## Independent Variables
Y = df['tip'] ## Dependent Variables

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %%
for col in ['sex', 'smoker']:
    X_train[col] = X_train[col].str.strip().str.lower()
    X_test[col]  = X_test[col].str.strip().str.lower()

# %%
X_train
# Out:
#      total_bill   tip     sex smoker   day
# 171       15.81  3.16    male    yes   Sat
# 89        21.16  3.00    male     no  Thur
# 157       25.00  3.75  female     no   Sun
# 219       30.14  3.09  female    yes   Sat
# 234       15.53  3.00    male    yes   Sat
# ..          ...   ...     ...    ...   ...
# 67         3.07  1.00  female    yes   Sat
# 192       28.44  2.56    male    yes  Thur
# 117       10.65  1.50  female     no  Thur
# 47        32.40  6.00    male     no   Sun
# 172        7.25  5.15    male    yes   Sun
#
# [183 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
le2 = LabelEncoder()
le3 = LabelEncoder()

# %%
X_train['sex'] = le1.fit_transform(X_train['sex'])
X_train['smoker'] = le2.fit_transform(X_train['smoker'])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct = ColumnTransformer(transformers=[('onehot',OneHotEncoder(drop='first'),[3])],remainder='passthrough')

# %%
ct.fit_transform(X_train)
# Out:
# array([[1.0, 15.81, 3.16, 'Male', 'Sat'],
#        [0.0, 21.16, 3.0, 'Male', 'Thur'],
#        [0.0, 25.0, 3.75, 'Female', 'Sun'],
#        [1.0, 30.14, 3.09, 'Female', 'Sat'],
#        [1.0, 15.53, 3.0, 'Male', 'Sat'],
#        [1.0, 16.47, 3.23, 'Female', 'Thur'],
#        [1.0, 32.83, 1.17, 'Male', 'Sat'],
#        [0.0, 10.33, 1.67, 'Female', 'Sun'],
#        [1.0, 28.97, 3.0, 'Male', 'Fri'],
#        [1.0, 15.38, 3.0, 'Female', 'Fri'],
#        [0.0, 10.51, 1.25, 'Male', 'Sat'],
#        [0.0, 24.59, 3.61, 'Female', 'Sun'],
#        [1.0, 14.31, 4.0, 'Female', 'Sat'],
#        [1.0, 13.81, 2.0, 'Male', 'Sat'],
#        [0.0, 18.64, 1.36, 'Female', 'Thur'],
#        [0.0, 34.81, 5.2, 'Female', 'Sun'],
#        [0.0, 16.45, 2.47, 'Female', 'Sat'],
#        [0.0, 13.37, 2.0, 'Male', 'Sat'],
#        [0.0, 18.26, 3.25, 'Female', 'Thur'],
#        [0.0, 8.51, 1.25, 'Female', 'Thur'],
#        [1.0, 11.59, 1.5, 'Male', 'Sat'],
#        [0.0, 16.04, 2.24, 'Male', 'Sat'],
#        [0.0, 18.43, 3.0, 'Male', 'Sun'],
#        [0.0, 23.68, 3.31, 'Male', 'Sun'],
#        [0.0, 17.26, 2.74, 'Male', 'Sun'],
#        [0.0, 19.82, 3.18, 'Male', 'Sat'],
#        [0.0, 9.55, 1.45, 'Male', 'Sat'],
#        [1.0, 7.74, 1.44, 'Male', 'Sat'],
#        [1.0, 20.29, 3.21, 'Male', 'Sat'],
#        [1.0, 38.01, 3.0, 'Male', 'Sat'],
#        [1.0, 34.63, 3.55, 'Male', 'Sun'],
#        [1.0, 28.17, 6.5, 'Female', 'Sat'],
#        [0.0, 20.65, 3.35, 'Male', 'Sat'],
#        [1.0, 45.35, 3.5, 'Male', 'Sun'],
#        [0.0, 22.82, 2.18, 'Male', 'Thur'],
#        [0.0, 25.56, 4.34, 'Male', 'Sun'],
#        [0.0, 35.83, 4.67, 'Female', 'Sat'],
#        [1.0, 19.44, 3.0, 'Male', 'Thur'],
#        [0.0, 10.29, 2.6, 'Female', 'Sun'],
#        [0.0, 15.95, 2.0, 'Male', 'Thur'],
#        [1.0, 12.74, 2.01, 'Female', 'Thur'],
#        [0.0, 19.08, 1.5, 'Male', 'Thur'],
#        [0.0, 13.03, 2.0, 'Male', 'Thur'],
#        [0.0, 10.27, 1.71, 'Male', 'Sun'],
#        [0.0, 14.15, 2.0, 'Female', 'Thur'],
#        [1.0, 31.85, 3.18, 'Male', 'Sun'],
#        [0.0, 8.52, 1.48, 'Male', 'Thur'],
#        [0.0, 17.46, 2.54, 'Male', 'Sun'],
#        [0.0, 14.83, 3.02, 'Female', 'Sun'],
#        [0.0, 12.69, 2.0, 'Male', 'Sat'],
#        [0.0, 12.54, 2.5, 'Male', 'Sun'],
#        [1.0, 13.42, 3.48, 'Female', 'Fri'],
#        [0.0, 17.92, 4.08, 'Male', 'Sat'],
#        [0.0, 16.21, 2.0, 'Female', 'Sun'],
#        [0.0, 22.23, 5.0, 'Male', 'Sun'],
#        [0.0, 20.76, 2.24, 'Male', 'Sun'],
#        [0.0, 29.03, 5.92, 'Male', 'Sat'],
#        [0.0, 21.5, 3.5, 'Male', 'Sun'],
#        [1.0, 50.81, 10.0, 'Male', 'Sat'],
#        [1.0, 11.02, 1.98, 'Male', 'Sat'],
#        [1.0, 15.69, 1.5, 'Male', 'Sun'],
#        [0.0, 16.49, 2.0, 'Male', 'Sun'],
#        [0.0, 21.01, 3.5, 'Male', 'Sun'],
#        [0.0, 48.27, 6.73, 'Male', 'Sat'],
#        [0.0, 7.51, 2.0, 'Male', 'Thur'],
#        [0.0, 20.45, 3.0, 'Male', 'Sat'],
#        [0.0, 9.68, 1.32, 'Male', 'Sun'],
#        [1.0, 19.81, 4.19, 'Female', 'Thur'],
#        [0.0, 13.16, 2.75, 'Female', 'Thur'],
#        [0.0, 19.77, 2.0, 'Male', 'Sun'],
#        [0.0, 38.07, 4.0, 'Male', 'Sun'],
#        [1.0, 26.59, 3.41, 'Male', 'Sat'],
#        [1.0, 21.01, 3.0, 'Male', 'Fri'],
#        [0.0, 24.55, 2.0, 'Male', 'Sun'],
#        [1.0, 16.32, 4.3, 'Female', 'Fri'],
#        [0.0, 16.43, 2.3, 'Female', 'Thur'],
#        [0.0, 10.77, 1.47, 'Male', 'Sat'],
#        [0.0, 23.95, 2.55, 'Male', 'Sun'],
#        [0.0, 16.99, 1.01, 'Female', 'Sun'],
#        [0.0, 22.75, 3.25, 'Female', 'Fri'],
#        [1.0, 40.17, 4.73, 'Male', 'Fri'],
#        [1.0, 15.01, 2.09, 'Male', 'Sat'],
#        [0.0, 18.04, 3.0, 'Male', 'Sun'],
#        [0.0, 28.55, 2.05, 'Male', 'Sun'],
#        [0.0, 34.83, 5.17, 'Female', 'Thur'],
#        [1.0, 22.67, 2.0, 'Male', 'Sat'],
#        [0.0, 34.3, 6.7, 'Male', 'Thur'],
#        [0.0, 39.42, 7.58, 'Male', 'Sat'],
#        [1.0, 12.9, 1.1, 'Female', 'Sat'],
#        [0.0, 27.05, 5.0, 'Female', 'Thur'],
#        [0.0, 22.76, 3.0, 'Male', 'Thur'],
#        [1.0, 11.35, 2.5, 'Female', 'Fri'],
#        [0.0, 20.27, 2.83, 'Female', 'Thur'],
#        [1.0, 10.34, 2.0, 'Male', 'Thur'],
#        [0.0, 17.82, 1.75, 'Male', 'Sat'],
#        [0.0, 8.77, 2.0, 'Male', 'Sun'],
#        [0.0, 20.23, 2.01, 'Male', 'Sat'],
#        [0.0, 15.98, 2.03, 'Male', 'Thur'],
#        [0.0, 13.42, 1.68, 'Female', 'Thur'],
#        [0.0, 13.28, 2.72, 'Male', 'Sat'],
#        [1.0, 40.55, 3.0, 'Male', 'Sun'],
#        [1.0, 38.73, 3.0, 'Male', 'Sat'],
#        [1.0, 13.0, 2.0, 'Female', 'Thur'],
#        [1.0, 20.9, 3.5, 'Female', 'Sun'],
#        [0.0, 22.49, 3.5, 'Male', 'Fri'],
#        [1.0, 13.27, 2.5, 'Female', 'Sat'],
#        [0.0, 35.26, 5.0, 'Female', 'Sun'],
#        [0.0, 24.08, 2.92, 'Female', 'Thur'],
#        [1.0, 44.3, 2.5, 'Female', 'Sat'],
#        [0.0, 24.06, 3.6, 'Male', 'Sat'],
#        [0.0, 26.41, 1.5, 'Female', 'Sat'],
#        [1.0, 10.63, 2.0, 'Female', 'Sat'],
#        [0.0, 20.08, 3.15, 'Male', 'Sat'],
#        [0.0, 10.34, 1.66, 'Male', 'Sun'],
#        [0.0, 11.69, 2.31, 'Male', 'Thur'],
#        [1.0, 16.58, 4.0, 'Male', 'Thur'],
#        [0.0, 13.94, 3.06, 'Male', 'Sun'],
#        [1.0, 15.36, 1.64, 'Male', 'Sat'],
#        [0.0, 11.17, 1.5, 'Female', 'Thur'],
#        [0.0, 10.07, 1.25, 'Male', 'Sat'],
#        [0.0, 16.29, 3.71, 'Male', 'Sun'],
#        [0.0, 18.69, 2.31, 'Male', 'Sat'],
#        [0.0, 12.26, 2.0, 'Female', 'Thur'],
#        [0.0, 9.94, 1.56, 'Male', 'Sun'],
#        [1.0, 17.51, 3.0, 'Female', 'Sun'],
#        [1.0, 30.46, 2.0, 'Male', 'Sun'],
#        [0.0, 11.38, 2.0, 'Female', 'Thur'],
#        [0.0, 17.78, 3.27, 'Male', 'Sat'],
#        [0.0, 21.7, 4.3, 'Male', 'Sat'],
#        [1.0, 23.17, 6.5, 'Male', 'Sun'],
#        [0.0, 25.71, 4.0, 'Female', 'Sun'],
#        [0.0, 13.81, 2.0, 'Male', 'Sun'],
#        [0.0, 13.13, 2.0, 'Male', 'Sun'],
#        [0.0, 18.35, 2.5, 'Male', 'Sat'],
#        [1.0, 18.71, 4.0, 'Male', 'Thur'],
#        [0.0, 14.52, 2.0, 'Female', 'Thur'],
#        [0.0, 20.69, 5.0, 'Male', 'Sun'],
#        [1.0, 24.01, 2.0, 'Male', 'Sat'],
#        [1.0, 10.09, 2.0, 'Female', 'Fri'],
#        [0.0, 15.06, 3.0, 'Female', 'Sat'],
#        [0.0, 31.71, 4.5, 'Male', 'Sun'],
#        [0.0, 41.19, 5.0, 'Male', 'Thur'],
#        [1.0, 20.53, 4.0, 'Male', 'Thur'],
#        [0.0, 11.87, 1.63, 'Female', 'Thur'],
#        [0.0, 19.65, 3.0, 'Female', 'Sat'],
#        [1.0, 14.48, 2.0, 'Male', 'Sun'],
#        [0.0, 12.46, 1.5, 'Male', 'Fri'],
#        [0.0, 10.07, 1.83, 'Female', 'Thur'],
#        [1.0, 27.18, 2.0, 'Female', 'Sat'],
#        [1.0, 32.9, 3.11, 'Male', 'Sun'],
#        [0.0, 17.29, 2.71, 'Male', 'Thur'],
#        [1.0, 43.11, 5.0, 'Female', 'Thur'],
#        [1.0, 24.27, 2.03, 'Male', 'Sat'],
#        [0.0, 17.31, 3.5, 'Female', 'Sun'],
#        [0.0, 9.78, 1.73, 'Male', 'Thur'],
#        [1.0, 12.6, 1.0, 'Male', 'Sat'],
#        [1.0, 26.86, 3.14, 'Female', 'Sat'],
#        [0.0, 27.2, 4.0, 'Male', 'Thur'],
#        [0.0, 17.81, 2.34, 'Male', 'Sat'],
#        [0.0, 24.52, 3.48, 'Male', 'Sun'],
#        [0.0, 16.66, 3.4, 'Male', 'Thur'],
#        [1.0, 22.12, 2.88, 'Female', 'Sat'],
#        [1.0, 16.82, 4.0, 'Male', 'Sun'],
#        [0.0, 11.61, 3.39, 'Male', 'Sat'],
#        [0.0, 31.27, 5.0, 'Male', 'Sat'],
#        [1.0, 15.48, 2.02, 'Male', 'Thur'],
#        [1.0, 11.24, 1.76, 'Male', 'Sat'],
#        [0.0, 17.47, 3.5, 'Female', 'Thur'],
#        [0.0, 24.71, 5.85, 'Male', 'Thur'],
#        [1.0, 28.15, 3.0, 'Male', 'Sat'],
#        [0.0, 12.02, 1.97, 'Male', 'Sat'],
#        [0.0, 18.28, 4.0, 'Male', 'Thur'],
#        [0.0, 16.31, 2.0, 'Male', 'Sat'],
#        [0.0, 20.29, 2.75, 'Female', 'Sat'],
#        [1.0, 25.89, 5.16, 'Male', 'Sat'],
#        [0.0, 14.78, 3.23, 'Male', 'Sun'],
#        [1.0, 22.42, 3.48, 'Female', 'Sat'],
#        [0.0, 7.56, 1.44, 'Male', 'Thur'],
#        [1.0, 3.07, 1.0, 'Female', 'Sat'],
#        [1.0, 28.44, 2.56, 'Male', 'Thur'],
#        [0.0, 10.65, 1.5, 'Female', 'Thur'],
#        [0.0, 32.4, 6.0, 'Male', 'Sun'],
#        [1.0, 7.25, 5.15, 'Male', 'Sun']], dtype=object)
